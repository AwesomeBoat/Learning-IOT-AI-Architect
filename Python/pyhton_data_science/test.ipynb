# %%
my_set = {1,2,3,3} # non-indexable
my_list = [1,2,3]
tupl = (1,2,3)
my_dict = {
    "cle" : "valeur"
}

my_dict["cle"] # methode mauvaise car plante le programme si clé n'existe pas

my_dict.get("cles") # Ne plante pas si la clé n'existe pas donc FAIRE DES .get

for index, value in enumerate(my_list):
    print(f"index : {index}, value : {value}")
# Out:
# index : 0, value : 1
# index : 1, value : 2
# index : 2, value : 3

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 big_list = list(range(1_000_000))
# ----> 2 print(sys.getsizeof(big_list)) ## (flawed) memory footprint estimate of *whole* object
#       3 get_ipython().run_line_magic('timeit', 'sum(big_list)')
#
# NameError: name 'sys' is not defined
