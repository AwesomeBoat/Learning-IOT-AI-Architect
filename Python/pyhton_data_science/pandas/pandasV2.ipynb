# %% [markdown]
# <font size="7"><p style="text-align: center;">**Gérer ses données avec python**</font></p>
# <br><br><br>
# <img src="img\pandas.svg">
#
# ## <u>1. Importer des données avec Pandas</u>
# Pandas offre une panoplie de connecteurs pour importer des données (CSV, Excel, SQL, hdfs, etc.).
#
# data source: https://www.kaggle.com/rashikrahmanpritom/heart-attack-analysis-prediction-dataset

# %%
# !pip install pyodbc
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pyodbc in C:\Users\e.vervaeren\AppData\Roaming\Python\Python314\site-packages (5.3.0)

# %%
# !pip install lxml
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: lxml in C:\Users\e.vervaeren\AppData\Roaming\Python\Python314\site-packages (6.1.1)

# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in C:\Users\e.vervaeren\AppData\Roaming\Python\Python314\site-packages (3.0.5)
# Requirement already satisfied: numpy>=2.3.3 in C:\Users\e.vervaeren\AppData\Roaming\Python\Python314\site-packages (from pandas) (2.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\e.vervaeren\AppData\Roaming\Python\Python314\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\e.vervaeren\AppData\Roaming\Python\Python314\site-packages (from pandas) (2026.3)
# Requirement already satisfied: six>=1.5 in C:\Users\e.vervaeren\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
# !uv add sqlalchemy
# Out:
# Resolved 47 packages in 1ms
# Checked 41 packages in 4ms

# %%
# %pip install requests
# Out:
# Note: you may need to restart the kernel to use updated packages.
# c:\Users\e.vervaeren\Desktop\Learning-IOT-AI-Architect\Python\pyhton_data_science\.venv\Scripts\python.exe: No module named pip

# %%
import numpy as np
import pandas as pd

import requests as rq
from io import StringIO
from sqlalchemy import create_engine

# %%
df = pd.read_csv("heart.csv")

# La méthode head() permet de n'afficher que les premières lignes (5 par défaut)
# Ici on en affiche 10
display(df.head(10))
display(df.tail())
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
# 5   57    1   0     140   192    0        1       148     0      0.4    1
# 6   56    0   1     140   294    0        0       153     0      1.3    1
# 7   44    1   1     120   263    0        1       173     0      0.0    2
# 8   52    1   2     172   199    1        1       162     0      0.5    2
# 9   57    1   2     150   168    0        1       174     0      1.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1
# 5    0      1       1
# 6    0      2       1
# 7    0      3       1
# 8    0      3       1
# 9    0      2       1
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 298    0      3       0
# 299    0      3       0
# 300    2      3       0
# 301    1      3       0
# 302    1      2       0

# %% [markdown]
# Il existe 2 structures de donnée dans pandas:
# - les **Series**: correspond à une colonne, à un numpy array avec un type de donnée unique
# - les **DataFrame**: correspond à une collection de **Series**

# %%
display(type(df))
type(df['age'])
# Out:
# pandas.DataFrame
# pandas.Series

# %% [markdown]
# Un DataFrame possède plusieurs attributs que l'on peut utiliser au besoin

# %%
print(df.shape)
print(50*'-')
print(df.size)
print(50*'-')
print(df.dtypes)
print(50*'-')
print(df.columns)
print(50*'-')
print(df.index)
print(50*'-')
print(df.values)
# Out:
# (303, 14)
# --------------------------------------------------
# 4242
# --------------------------------------------------
# age           int64
# sex           int64
# cp            int64
# trtbps        int64
# chol          int64
# fbs           int64
# restecg       int64
# thalachh      int64
# exng          int64
# oldpeak     float64
# slp           int64
# caa           int64
# thall         int64
# output        int64
# dtype: object
# --------------------------------------------------
# Index(['age', 'sex', 'cp', 'trtbps', 'chol', 'fbs', 'restecg', 'thalachh',
#        'exng', 'oldpeak', 'slp', 'caa', 'thall', 'output'],
#       dtype='str')
# --------------------------------------------------
# RangeIndex(start=0, stop=303, step=1)
# --------------------------------------------------
# [[63.  1.  3. ...  0.  1.  1.]
#  [37.  1.  2. ...  0.  2.  1.]
#  [41.  0.  1. ...  0.  2.  1.]
#  ...
#  [68.  1.  0. ...  2.  3.  0.]
#  [57.  1.  0. ...  1.  3.  0.]
#  [57.  0.  1. ...  1.  2.  0.]]

# %% [markdown]
# Méthode info() : La méthode info() nous renvoi un condensé d'informations utiles concernant notre dataframe

# %%
df.info() # Must know
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trtbps    303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalachh  303 non-null    int64
#  8   exng      303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slp       303 non-null    int64
#  11  caa       303 non-null    int64
#  12  thall     303 non-null    int64
#  13  output    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %% [markdown]
# ## <u>2. Comment manipuler ses données avec pandas ?</u>

# %% [markdown]
# **2.1. Indexation et colonnes**

# %%
df[['age','cp']].head()
# Out:
#    age  cp
# 0   63   3
# 1   37   2
# 2   41   1
# 3   56   1
# 4   57   0

# %%
df['age'].head()

df["age"].head() # => Ceci est un dataframe car " "
# Out:
# 0    63
# 1    37
# 2    41
# 3    56
# 4    57
# Name: age, dtype: int64

# %%
df.age
# Out:
# 0      63
# 1      37
# 2      41
# 3      56
# 4      57
#        ..
# 298    57
# 299    45
# 300    68
# 301    57
# 302    57
# Name: age, Length: 303, dtype: int64

# %%
test = pd.DataFrame({'prenom':["Georges","Jules","Max"],
                     'age':[20,25,30]},index=['a','b','c'])
display(test)
test.loc['a':'c',['prenom','age']]
# Out:
#     prenom  age
# a  Georges   20
# b    Jules   25
# c      Max   30
#     prenom  age
# a  Georges   20
# b    Jules   25
# c      Max   30

# %%
df.loc[10:20,["age","cp"]]   # dF.loc[indexDebut:indexFin, nomattribut]  loc est inclusif
# Out:
#     age  cp
# 10   54   0
# 11   48   2
# 12   49   1
# 13   64   3
# 14   58   3
# 15   50   2
# 16   58   2
# 17   66   3
# 18   43   0
# 19   69   3
# 20   59   0

# %%
df.iloc[5:10,0:5] # index ligne , index colonne
# Out:
#    age  sex  cp  trtbps  chol
# 5   57    1   0     140   192
# 6   56    0   1     140   294
# 7   44    1   1     120   263
# 8   52    1   2     172   199
# 9   57    1   2     150   168

# %%
df.at[0,'age']
# Out:
# np.int64(63)

# %%
df.iat[0,0]
# Out:
# np.int64(63)

# %%
# Avec le slicing, comme pour les listes python
# En ne sélectionnant qu'une seule ligne
data_sliced = df.loc[[10]]
display(data_sliced)
# Selectionner plusieurs lignes avec une list ou une array
data_sliced2 = df.loc[[10,20,30]]
display(data_sliced2)
# Selectionner sur base de l'index et des noms de colonnes
data_sliced3 = df.loc[[10,20,30],['age','chol']]
display(data_sliced3)
data_sliced4 = df[['age','chol']].loc[1:5]
display(data_sliced4)
print(df.age)

display(data_sliced3.dtypes)
data_sliced4.dtypes
# Out:
#     age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 10   54    1   0     140   239    0        1       160     0      1.2    2
#
#     caa  thall  output
# 10    0      2       1
#     age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 10   54    1   0     140   239    0        1       160     0      1.2    2
# 20   59    1   0     135   234    0        1       161     0      0.5    1
# 30   41    0   1     105   198    0        1       168     0      0.0    2
#
#     caa  thall  output
# 10    0      2       1
# 20    0      3       1
# 30    1      2       1
#     age  chol
# 10   54   239
# 20   59   234
# 30   41   198
#    age  chol
# 1   37   250
# 2   41   204
# 3   56   236
# 4   57   354
# 5   57   192
# 0      63
# 1      37
# 2      41
# 3      56
# 4      57
#        ..
# 298    57
# 299    45
# 300    68
# 301    57
# 302    57
# Name: age, Length: 303, dtype: int64
# age     int64
# chol    int64
# dtype: object
# age     int64
# chol    int64
# dtype: object

# %%
df[1:10]
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
# 5   57    1   0     140   192    0        1       148     0      0.4    1
# 6   56    0   1     140   294    0        0       153     0      1.3    1
# 7   44    1   1     120   263    0        1       173     0      0.0    2
# 8   52    1   2     172   199    1        1       162     0      0.5    2
# 9   57    1   2     150   168    0        1       174     0      1.6    2
#
#    caa  thall  output
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1
# 5    0      1       1
# 6    0      2       1
# 7    0      3       1
# 8    0      3       1
# 9    0      2       1

# %%
df.loc[:0,'age':'cp']
# Out:
#    age  sex  cp
# 0   63    1   3

# %%
# En sélectionnant un range
data_sliced = df.loc[74:80]
data_sliced
# Out:
#     age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 74   43    0   2     122   213    0        1       165     0      0.2    1
# 75   55    0   1     135   250    0        0       161     0      1.4    1
# 76   51    1   2     125   245    1        0       166     0      2.4    1
# 77   59    1   1     140   221    0        1       164     1      0.0    2
# 78   52    1   1     128   205    1        1       184     0      0.0    2
# 79   58    1   2     105   240    0        0       154     1      0.6    1
# 80   41    1   2     112   250    0        1       179     0      0.0    2
#
#     caa  thall  output
# 74    0      2       1
# 75    0      2       1
# 76    0      2       1
# 77    0      2       1
# 78    0      2       1
# 79    0      3       1
# 80    0      2       1

# %%
df.iloc[5:8,[1,5]]
# Out:
#    sex  fbs
# 5    1    0
# 6    0    0
# 7    1    0

# %%
df.at[0,'age']
# Out:
# np.int64(63)

# %%
df.iat[0,0]
# Out:
# np.int64(63)

# %%
# Il est également possible de ne sélectionner qu'une colonne en particulier
# Avec les crochets et la colonne voulue
data_sliced = df[['age','chol']]
data_sliced
data_chol = df['chol']
print (data_sliced)
data_chol
# Out:
#      age  chol
# 0     63   233
# 1     37   250
# 2     41   204
# 3     56   236
# 4     57   354
# ..   ...   ...
# 298   57   241
# 299   45   264
# 300   68   193
# 301   57   131
# 302   57   236
#
# [303 rows x 2 columns]
# 0      233
# 1      250
# 2      204
# 3      236
# 4      354
#       ...
# 298    241
# 299    264
# 300    193
# 301    131
# 302    236
# Name: chol, Length: 303, dtype: int64

# %%
# Avec plusieurs colonnes
# A noter les doubles crochets
data_sliced = df[['age','output']].loc[54:60]
data_sliced
# Out:
#     age  output
# 54   63       1
# 55   52       1
# 56   48       1
# 57   45       1
# 58   34       1
# 59   57       1
# 60   71       1

# %% [markdown]
# **2.2. Boolean indexing**
#
# Nous avons vu jusqu'ici comment sélectionner des parties de notre DataFrame avec les indexes ou le nom des colonnes.
#
# Nous pourrions également faire une sélection basée sur des conditions.
#
# C'est ce que l'on appelle le **boolean indexing**.

# %%
df['age']>58
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 298    False
# 299    False
# 300     True
# 301    False
# 302    False
# Name: age, Length: 303, dtype: bool

# %%
# On ne sélectionne que les personnes plus agées que 58 ans
data_sliced = df[df['age'] > 58]
data_sliced
data_sliced2= df[df['age']>58].loc[0:50]
display(data_sliced2)
print(data_sliced2.loc[38])
print(data_sliced2.iloc[10])
# Out:
#     age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0    63    1   3     145   233    1        0       150     0      2.3    0
# 13   64    1   3     110   211    0        0       144     1      1.8    1
# 17   66    0   3     150   226    0        1       114     0      2.6    0
# 19   69    0   3     140   239    0        1       151     0      1.8    2
# 20   59    1   0     135   234    0        1       161     0      0.5    1
# 23   61    1   2     150   243    1        1       137     1      1.0    1
# 25   71    0   1     160   302    0        1       162     0      0.4    2
# 26   59    1   2     150   212    1        1       157     0      1.6    2
# 28   65    0   2     140   417    1        0       157     0      0.8    2
# 31   65    1   0     120   177    0        1       140     0      0.4    2
# 38   65    0   2     155   269    0        1       148     0      0.8    2
# 39   65    0   2     160   360    0        0       151     0      0.8    2
#
#     caa  thall  output
# 0     0      1       1
# 13    0      2       1
# 17    0      2       1
# 19    2      2       1
# 20    0      3       1
# 23    0      2       1
# 25    2      2       1
# 26    0      2       1
# 28    1      2       1
# 31    0      3       1
# 38    0      2       1
# 39    0      2       1
# age          65.0
# sex           0.0
# cp            2.0
# trtbps      155.0
# chol        269.0
# fbs           0.0
# restecg       1.0
# thalachh    148.0
# exng          0.0
# oldpeak       0.8
# slp           2.0
# caa           0.0
# thall         2.0
# output        1.0
# Name: 38, dtype: float64
# age          65.0
# sex           0.0
# cp            2.0
# trtbps      155.0
# chol        269.0
# fbs           0.0
# restecg       1.0
# thalachh    148.0
# exng          0.0
# oldpeak       0.8
# slp           2.0
# caa           0.0
# thall         2.0
# output        1.0
# Name: 38, dtype: float64

# %% [markdown]
# On peut également mettre plusieurs conditions.
#
# **Attention:** les opérateurs logiques "and" et "or" classiques de Python ne fonctionnent pas.
#
# Il faut impérativement utiliser les opérateurs **&** et **|** et mettre des **()** autour des conditions.

# %%
data_sliced2 = df[(df['age'] > 58) & (df['output'] == 1)]
data_sliced2.head()
# Out:
#     age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0    63    1   3     145   233    1        0       150     0      2.3    0
# 13   64    1   3     110   211    0        0       144     1      1.8    1
# 17   66    0   3     150   226    0        1       114     0      2.6    0
# 19   69    0   3     140   239    0        1       151     0      1.8    2
# 20   59    1   0     135   234    0        1       161     0      0.5    1
#
#     caa  thall  output
# 0     0      1       1
# 13    0      2       1
# 17    0      2       1
# 19    2      2       1
# 20    0      3       1

# %% [markdown]
# Il est possible de créer de nouvelles colonnes de manière à enrichir vos données.

# %%
# Ici on souhaite créer une colonne basée sur la colonne age de manière à obtenir des catégories
# On l'instancie d'abord à 'unknown'
df['age_cat'] = np.nan
display(df.head())
del df['age_cat']
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output  age_cat
# 0    0      1       1      NaN
# 1    0      2       1      NaN
# 2    0      2       1      NaN
# 3    0      2       1      NaN
# 4    0      2       1      NaN

# %%
df['newcol'] = df['age']*df['oldpeak']
display(df.head())
df.drop(columns=['newcol'],inplace=True) #inplace True permetr d'altérer
#df = df.drop(columns=['newcol'])
#df.head()
df
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output  newcol
# 0    0      1       1   144.9
# 1    0      2       1   129.5
# 2    0      2       1    57.4
# 3    0      2       1    44.8
# 4    0      2       1    34.2
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# 1      0      2       1
# 2      0      2       1
# 3      0      2       1
# 4      0      2       1
# ..   ...    ...     ...
# 298    0      3       0
# 299    0      3       0
# 300    2      3       0
# 301    1      3       0
# 302    1      2       0
#
# [303 rows x 14 columns]

# %%
# Nous allons utiliser le boolean indexing pour modifier la catégorie
# Attention à utiliser .loc lorsque l'on chercher un modifier des valeurs
df.loc[df['age'] <= 18, 'age_cat'] = 'child'
display(df)
df.loc[(df['age'] > 18) & (df['age'] < 66), 'age_cat'] = 'adult'
df.loc[df['age'] > 65, 'age_cat'] = 'senior'
df
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output age_cat
# 0      0      1       1     NaN
# 1      0      2       1     NaN
# 2      0      2       1     NaN
# 3      0      2       1     NaN
# 4      0      2       1     NaN
# ..   ...    ...     ...     ...
# 298    0      3       0     NaN
# 299    0      3       0     NaN
# 300    2      3       0     NaN
# 301    1      3       0     NaN
# 302    1      2       0     NaN
#
# [303 rows x 15 columns]
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output age_cat
# 0      0      1       1   adult
# 1      0      2       1   adult
# 2      0      2       1   adult
# 3      0      2       1   adult
# 4      0      2       1   adult
# ..   ...    ...     ...     ...
# 298    0      3       0   adult
# 299    0      3       0   adult
# 300    2      3       0  senior
# 301    1      3       0   adult
# 302    1      2       0   adult
#
# [303 rows x 15 columns]

# %% [markdown]
# ## <u>3. Opérations mathématiques</u>
# - Pandas supporte bien évidemment toutes les opérations mathématiques de base
# - Pandas supporte également toutes les opérations de numpy

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trtbps    303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalachh  303 non-null    int64
#  8   exng      303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slp       303 non-null    int64
#  11  caa       303 non-null    int64
#  12  thall     303 non-null    int64
#  13  output    303 non-null    int64
#  14  age_cat   303 non-null    str
# dtypes: float64(1), int64(13), str(1)
# memory usage: 35.6 KB

# %%
data_math = df.copy()
# Addition d'une constante à l'entièreté d'une colonne
data_math['age'] += 100
# identique a data_math['age'] = data_math['age'] +100
data_math
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0    163    1   3     145   233    1        0       150     0      2.3    0
# 1    137    1   2     130   250    0        1       187     0      3.5    0
# 2    141    0   1     130   204    0        0       172     0      1.4    2
# 3    156    1   1     120   236    0        1       178     0      0.8    2
# 4    157    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298  157    0   0     140   241    0        1       123     1      0.2    1
# 299  145    1   3     110   264    0        1       132     0      1.2    1
# 300  168    1   0     144   193    1        1       141     0      3.4    1
# 301  157    1   0     130   131    0        1       115     1      1.2    1
# 302  157    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output age_cat
# 0      0      1       1   adult
# 1      0      2       1   adult
# 2      0      2       1   adult
# 3      0      2       1   adult
# 4      0      2       1   adult
# ..   ...    ...     ...     ...
# 298    0      3       0   adult
# 299    0      3       0   adult
# 300    2      3       0  senior
# 301    1      3       0   adult
# 302    1      2       0   adult
#
# [303 rows x 15 columns]

# %%
# On peut également additionner les colonnes entre elles
data_math['age'] = data_math['age']+data_math['chol']

# %% [markdown]
# On peut retrouver toutes les fonctions mathématiques de numpy ici:
#
# https://numpy.org/doc/stable/reference/routines.math.html

# %%
data_math['age'] = np.log1p(data_math['age'])
data_math
data_test = np.sum(data_math['age'])
data_test
# Out:
# np.float64(1814.005681170679)

# %% [markdown]
# ## <u>4. Agrégations et statistiques</u>
# Tout comme avec numpy, il est possible d'agréger nos données selon un axe spécifique.
#
# Pandas fournit également quelque statistiques de base.

# %%
# Par défaut axis=0
df.sum(axis=0)
# Out:
# age                                                     16473
# sex                                                       207
# cp                                                        293
# trtbps                                                  39882
# chol                                                    74618
# fbs                                                        45
# restecg                                                   160
# thalachh                                                45343
# exng                                                       99
# oldpeak                                                 315.0
# slp                                                       424
# caa                                                       221
# thall                                                     701
# output                                                    165
# age_cat     adultadultadultadultadultadultadultadultadulta...
# dtype: object

# %%
df.sum(axis=1,numeric_only=True)  # numeric_only=True
# Out:
# 0      600.3
# 1      614.5
# 2      554.4
# 3      598.8
# 4      701.6
#        ...
# 298    567.2
# 299    561.2
# 300    558.4
# 301    442.2
# 302    602.0
# Length: 303, dtype: float64

# %%
df['age'].astype(float)
# Out:
# 0      63.0
# 1      37.0
# 2      41.0
# 3      56.0
# 4      57.0
#        ...
# 298    57.0
# 299    45.0
# 300    68.0
# 301    57.0
# 302    57.0
# Name: age, Length: 303, dtype: float64

# %%
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output age_cat
# 0    0      1       1   adult
# 1    0      2       1   adult
# 2    0      2       1   adult
# 3    0      2       1   adult
# 4    0      2       1   adult

# %%
# Imaginons que nous devions calculer la moyenne pour chaque colonne
print(data_math.shape)
print(data_math.sum(numeric_only=True)/data_math.shape[0])
print(data_math.sum(axis=1,numeric_only=True)/data_math.shape[1])
# Out:
# (303, 15)
# age           5.986817
# sex           0.683168
# cp            0.966997
# trtbps      131.623762
# chol        246.264026
# fbs           0.148515
# restecg       0.528053
# thalachh    149.646865
# exng          0.326733
# oldpeak       1.039604
# slp           1.399340
# caa           0.729373
# thall         2.313531
# output        0.544554
# dtype: float64
# 0      36.218929
# 1      38.897400
# 2      34.616429
# 3      36.584921
# 4      43.389222
#          ...
# 298    34.412597
# 299    34.814410
# 300    33.086110
# 301    26.057762
# 302    36.731757
# Length: 303, dtype: float64

# %%
# Plus simple comme ceci:
print(df[['age','chol']].quantile(0.25))
df[['age','chol']].loc[1:20].mean()
# Out:
# age      47.5
# chol    211.0
# Name: 0.25, dtype: float64
# age      53.75
# chol    246.95
# dtype: float64

# %%
# Lien de corrélation
df.corr(numeric_only=True)
# Out:
#                age       sex        cp    trtbps      chol       fbs  \
# age       1.000000 -0.098447 -0.068653  0.279351  0.213678  0.121308
# sex      -0.098447  1.000000 -0.049353 -0.056769 -0.197912  0.045032
# cp       -0.068653 -0.049353  1.000000  0.047608 -0.076904  0.094444
# trtbps    0.279351 -0.056769  0.047608  1.000000  0.123174  0.177531
# chol      0.213678 -0.197912 -0.076904  0.123174  1.000000  0.013294
# fbs       0.121308  0.045032  0.094444  0.177531  0.013294  1.000000
# restecg  -0.116211 -0.058196  0.044421 -0.114103 -0.151040 -0.084189
# thalachh -0.398522 -0.044020  0.295762 -0.046698 -0.009940 -0.008567
# exng      0.096801  0.141664 -0.394280  0.067616  0.067023  0.025665
# oldpeak   0.210013  0.096093 -0.149230  0.193216  0.053952  0.005747
# slp      -0.168814 -0.030711  0.119717 -0.121475 -0.004038 -0.059894
# caa       0.276326  0.118261 -0.181053  0.101389  0.070511  0.137979
# thall     0.068001  0.210041 -0.161736  0.062210  0.098803 -0.032019
# output   -0.225439 -0.280937  0.433798 -0.144931 -0.085239 -0.028046
#
#            restecg  thalachh      exng   oldpeak       slp       caa  \
# age      -0.116211 -0.398522  0.096801  0.210013 -0.168814  0.276326
# sex      -0.058196 -0.044020  0.141664  0.096093 -0.030711  0.118261
# cp        0.044421  0.295762 -0.394280 -0.149230  0.119717 -0.181053
# trtbps   -0.114103 -0.046698  0.067616  0.193216 -0.121475  0.101389
# chol     -0.151040 -0.009940  0.067023  0.053952 -0.004038  0.070511
# fbs      -0.084189 -0.008567  0.025665  0.005747 -0.059894  0.137979
# restecg   1.000000  0.044123 -0.070733 -0.058770  0.093045 -0.072042
# thalachh  0.044123  1.000000 -0.378812 -0.344187  0.386784 -0.213177
# exng     -0.070733 -0.378812  1.000000  0.288223 -0.257748  0.115739
# oldpeak  -0.058770 -0.344187  0.288223  1.000000 -0.577537  0.222682
# slp       0.093045  0.386784 -0.257748 -0.577537  1.000000 -0.080155
# caa      -0.072042 -0.213177  0.115739  0.222682 -0.080155  1.000000
# thall    -0.011981 -0.096439  0.206754  0.210244 -0.104764  0.151832
# output    0.137230  0.421741 -0.436757 -0.430696  0.345877 -0.391724
#
#              thall    output
# age       0.068001 -0.225439
# sex       0.210041 -0.280937
# cp       -0.161736  0.433798
# trtbps    0.062210 -0.144931
# chol      0.098803 -0.085239
# fbs      -0.032019 -0.028046
# restecg  -0.011981  0.137230
# thalachh -0.096439  0.421741
# exng      0.206754 -0.436757
# oldpeak   0.210244 -0.430696
# slp      -0.104764  0.345877
# caa       0.151832 -0.391724
# thall     1.000000 -0.344029
# output   -0.344029  1.000000

# %% [markdown]
# Nous avons vu comment créer des catégories. Comment calculer la moyenne par exemple en fonction de ces catégories?
#
# Avec la fonction **groupby** comme en SQL.

# %%
df.groupby(by=['age_cat']).mean()
# Out:
#                age       sex        cp      trtbps        chol       fbs  \
# age_cat
# adult    52.625926  0.692593  0.955556  130.911111  244.959259  0.144444
# senior   68.606061  0.606061  1.060606  137.454545  256.939394  0.181818
#
#           restecg    thalachh      exng   oldpeak       slp       caa  \
# age_cat
# adult    0.533333  151.337037  0.325926  1.026296  1.414815  0.674074
# senior   0.484848  135.818182  0.333333  1.148485  1.272727  1.181818
#
#             thall    output
# age_cat
# adult    2.318519  0.548148
# senior   2.272727  0.515152

# %%
df.groupby(by=['age_cat','output'],as_index=False).mean()
# Out:
#   age_cat  output        age       sex        cp      trtbps        chol  \
# 0   adult       0  55.073770  0.811475  0.467213  133.573770  251.286885
# 1   adult       1  50.608108  0.594595  1.358108  128.716216  239.743243
# 2  senior       0  68.250000  0.937500  0.562500  140.687500  249.562500
# 3  senior       1  68.941176  0.294118  1.529412  134.411765  263.882353
#
#         fbs   restecg    thalachh      exng   oldpeak       slp       caa  \
# 0  0.147541  0.450820  140.065574  0.540984  1.604918  1.180328  1.098361
# 1  0.141892  0.601351  160.628378  0.148649  0.549324  1.608108  0.324324
# 2  0.250000  0.437500  131.750000  0.625000  1.437500  1.062500  1.687500
# 3  0.117647  0.529412  139.647059  0.058824  0.876471  1.470588  0.705882
#
#       thall
# 0  2.549180
# 1  2.128378
# 2  2.500000
# 3  2.058824

# %%
df.groupby(by=['age_cat','output']).mean().reset_index()
# Out:
#   age_cat  output        age       sex        cp      trtbps        chol  \
# 0   adult       0  55.073770  0.811475  0.467213  133.573770  251.286885
# 1   adult       1  50.608108  0.594595  1.358108  128.716216  239.743243
# 2  senior       0  68.250000  0.937500  0.562500  140.687500  249.562500
# 3  senior       1  68.941176  0.294118  1.529412  134.411765  263.882353
#
#         fbs   restecg    thalachh      exng   oldpeak       slp       caa  \
# 0  0.147541  0.450820  140.065574  0.540984  1.604918  1.180328  1.098361
# 1  0.141892  0.601351  160.628378  0.148649  0.549324  1.608108  0.324324
# 2  0.250000  0.437500  131.750000  0.625000  1.437500  1.062500  1.687500
# 3  0.117647  0.529412  139.647059  0.058824  0.876471  1.470588  0.705882
#
#       thall
# 0  2.549180
# 1  2.128378
# 2  2.500000
# 3  2.058824

# %%
df.drop(columns=['age_cat'],inplace=True)

# %%
# Il suffit de spécifier la colonne
df.loc[df['age'] <= 18, 'age_cat'] = 'child'
df.loc[(df['age'] > 18) & (df['age'] < 66), 'age_cat'] = 'adult'
df.loc[df['age'] > 65, 'age_cat'] = 'senior'
grouped_data = df.groupby(['age_cat','output']).mean(numeric_only=True)
display(grouped_data)
grouped_data.reset_index()
# Out:
#                       age       sex        cp      trtbps        chol  \
# age_cat output
# adult   0       61.942623  0.811475  0.467213  133.573770  251.286885
#         1       62.621622  0.594595  1.358108  128.716216  239.743243
# senior  0       68.250000  0.937500  0.562500  140.687500  249.562500
#         1       68.941176  0.294118  1.529412  134.411765  263.882353
#
#                      fbs   restecg    thalachh      exng   oldpeak       slp  \
# age_cat output
# adult   0       0.147541  0.450820  140.065574  0.540984  1.604918  1.180328
#         1       0.141892  0.601351  160.628378  0.148649  0.549324  1.608108
# senior  0       0.250000  0.437500  131.750000  0.625000  1.437500  1.062500
#         1       0.117647  0.529412  139.647059  0.058824  0.876471  1.470588
#
#                      caa     thall
# age_cat output
# adult   0       1.098361  2.549180
#         1       0.324324  2.128378
# senior  0       1.687500  2.500000
#         1       0.705882  2.058824
#   age_cat  output        age       sex        cp      trtbps        chol  \
# 0   adult       0  61.942623  0.811475  0.467213  133.573770  251.286885
# 1   adult       1  62.621622  0.594595  1.358108  128.716216  239.743243
# 2  senior       0  68.250000  0.937500  0.562500  140.687500  249.562500
# 3  senior       1  68.941176  0.294118  1.529412  134.411765  263.882353
#
#         fbs   restecg    thalachh      exng   oldpeak       slp       caa  \
# 0  0.147541  0.450820  140.065574  0.540984  1.604918  1.180328  1.098361
# 1  0.141892  0.601351  160.628378  0.148649  0.549324  1.608108  0.324324
# 2  0.250000  0.437500  131.750000  0.625000  1.437500  1.062500  1.687500
# 3  0.117647  0.529412  139.647059  0.058824  0.876471  1.470588  0.705882
#
#       thall
# 0  2.549180
# 1  2.128378
# 2  2.500000
# 3  2.058824

# %%
grouped_data.index
# Out:
# MultiIndex([( 'adult', 0),
#             ( 'adult', 1),
#             ('senior', 0),
#             ('senior', 1)],
#            names=['age_cat', 'output'])

# %%
df.groupby(['age_cat','output']).agg({'age':['mean','max','min'],
                                        'chol':'max'})
# Out:
#                       age             chol
#                      mean   max   min  max
# age_cat output
# adult   0       61.942623  65.0  58.0  409
#         1       62.621622  65.0  58.0  417
# senior  0       68.250000  77.0  66.0  322
#         1       68.941176  76.0  66.0  564

# %%
# Nous n'avons pas la catégorie child, pourquoi?
# Value counts permet d'inventorier nos valeurs catégorielles
df['age_cat'].value_counts()
# Out:
# age_cat
# adult     270
# senior     33
# Name: count, dtype: int64

# %%
df.drop_duplicates()
# Out:
#       age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0    63.0    1   3     145   233    1        0       150     0      2.3    0
# 1    63.0    1   2     130   250    0        1       187     0      3.5    0
# 2    63.0    0   1     130   204    0        0       172     0      1.4    2
# 3    63.0    1   1     120   236    0        1       178     0      0.8    2
# 4    63.0    0   0     120   354    0        1       163     1      0.6    2
# ..    ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298  63.0    0   0     140   241    0        1       123     1      0.2    1
# 299  63.0    1   3     110   264    0        1       132     0      1.2    1
# 300  68.0    1   0     144   193    1        1       141     0      3.4    1
# 301  63.0    1   0     130   131    0        1       115     1      1.2    1
# 302  63.0    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output age_cat
# 0      0      1       1   adult
# 1      0      2       1   adult
# 2      0      2       1   adult
# 3      0      2       1   adult
# 4      0      2       1   adult
# ..   ...    ...     ...     ...
# 298    0      3       0   adult
# 299    0      3       0   adult
# 300    2      3       0  senior
# 301    1      3       0   adult
# 302    1      2       0   adult
#
# [302 rows x 15 columns]

# %%
display(df.duplicated())
df[df.duplicated()]
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 298    False
# 299    False
# 300    False
# 301    False
# 302    False
# Length: 303, dtype: bool
#       age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 164  63.0    1   2     138   175    0        1       173     0      0.0    2
#
#      caa  thall  output age_cat
# 164    4      2       1   adult

# %%
# Vérifions
print(df['age'].min())
df['age'].max()
# Out:
# 58.0
# np.float64(77.0)

# %%
# La fonction describe permet d'obtenir une vision très macro de vos données
display(df.describe(include='all').T)
df.describe(include='all')
# Out:
#           count unique    top freq        mean        std    min    25%  \
# age       303.0    NaN    NaN  NaN        63.0     2.6818   58.0   63.0
# sex       303.0    NaN    NaN  NaN    0.683168   0.466011    0.0    0.0
# cp        303.0    NaN    NaN  NaN    0.966997   1.032052    0.0    0.0
# trtbps    303.0    NaN    NaN  NaN  131.623762  17.538143   94.0  120.0
# chol      303.0    NaN    NaN  NaN  246.264026  51.830751  126.0  211.0
# fbs       303.0    NaN    NaN  NaN    0.148515   0.356198    0.0    0.0
# restecg   303.0    NaN    NaN  NaN    0.528053    0.52586    0.0    0.0
# thalachh  303.0    NaN    NaN  NaN  149.646865  22.905161   71.0  133.5
# exng      303.0    NaN    NaN  NaN    0.326733   0.469794    0.0    0.0
# oldpeak   303.0    NaN    NaN  NaN    1.039604   1.161075    0.0    0.0
# slp       303.0    NaN    NaN  NaN     1.39934   0.616226    0.0    1.0
# caa       303.0    NaN    NaN  NaN    0.729373   1.022606    0.0    0.0
# thall     303.0    NaN    NaN  NaN    2.313531   0.612277    0.0    2.0
# output    303.0    NaN    NaN  NaN    0.544554   0.498835    0.0    0.0
# age_cat     303      2  adult  270         NaN        NaN    NaN    NaN
#
#             50%    75%    max
# age        63.0   63.0   77.0
# sex         1.0    1.0    1.0
# cp          1.0    2.0    3.0
# trtbps    130.0  140.0  200.0
# chol      240.0  274.5  564.0
# fbs         0.0    0.0    1.0
# restecg     1.0    1.0    2.0
# thalachh  153.0  166.0  202.0
# exng        0.0    1.0    1.0
# oldpeak     0.8    1.6    6.2
# slp         1.0    2.0    2.0
# caa         0.0    1.0    4.0
# thall       2.0    3.0    3.0
# output      1.0    1.0    1.0
# age_cat     NaN    NaN    NaN
#              age         sex          cp      trtbps        chol         fbs  \
# count   303.0000  303.000000  303.000000  303.000000  303.000000  303.000000
# unique       NaN         NaN         NaN         NaN         NaN         NaN
# top          NaN         NaN         NaN         NaN         NaN         NaN
# freq         NaN         NaN         NaN         NaN         NaN         NaN
# mean     63.0000    0.683168    0.966997  131.623762  246.264026    0.148515
# std       2.6818    0.466011    1.032052   17.538143   51.830751    0.356198
# min      58.0000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%      63.0000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%      63.0000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%      63.0000    1.000000    2.000000  140.000000  274.500000    0.000000
# max      77.0000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#            restecg    thalachh        exng     oldpeak         slp  \
# count   303.000000  303.000000  303.000000  303.000000  303.000000
# unique         NaN         NaN         NaN         NaN         NaN
# top            NaN         NaN         NaN         NaN         NaN
# freq           NaN         NaN         NaN         NaN         NaN
# mean      0.528053  149.646865    0.326733    1.039604    1.399340
# std       0.525860   22.905161    0.469794    1.161075    0.616226
# min       0.000000   71.000000    0.000000    0.000000    0.000000
# 25%       0.000000  133.500000    0.000000    0.000000    1.000000
# 50%       1.000000  153.000000    0.000000    0.800000    1.000000
# 75%       1.000000  166.000000    1.000000    1.600000    2.000000
# max       2.000000  202.000000    1.000000    6.200000    2.000000
#
#                caa       thall      output age_cat
# count   303.000000  303.000000  303.000000     303
# unique         NaN         NaN         NaN       2
# top            NaN         NaN         NaN   adult
# freq           NaN         NaN         NaN     270
# mean      0.729373    2.313531    0.544554     NaN
# std       1.022606    0.612277    0.498835     NaN
# min       0.000000    0.000000    0.000000     NaN
# 25%       0.000000    2.000000    0.000000     NaN
# 50%       0.000000    2.000000    1.000000     NaN
# 75%       1.000000    3.000000    1.000000     NaN
# max       4.000000    3.000000    1.000000     NaN

# %% [markdown]
# ## <u>5. Comment gérer les valeurs manquantes:</u>

# %%
# D'abord modifions notre dataset de sorte à avoir des données manquantes
# nan correspond à Null, aux valeurs manquantes
# Ici l'âge pour toutes les personnes de moins de 58 ans sera à NaN
df.loc[df['age'] < 58, 'age'] = np.nan
df
# Out:
#       age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0    63.0    1   3     145   233    1        0       150     0      2.3    0
# 1     NaN    1   2     130   250    0        1       187     0      3.5    0
# 2     NaN    0   1     130   204    0        0       172     0      1.4    2
# 3     NaN    1   1     120   236    0        1       178     0      0.8    2
# 4     NaN    0   0     120   354    0        1       163     1      0.6    2
# ..    ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   NaN    0   0     140   241    0        1       123     1      0.2    1
# 299   NaN    1   3     110   264    0        1       132     0      1.2    1
# 300  68.0    1   0     144   193    1        1       141     0      3.4    1
# 301   NaN    1   0     130   131    0        1       115     1      1.2    1
# 302   NaN    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output age_cat
# 0      0      1       1   adult
# 1      0      2       1   adult
# 2      0      2       1   adult
# 3      0      2       1   adult
# 4      0      2       1   adult
# ..   ...    ...     ...     ...
# 298    0      3       0   adult
# 299    0      3       0   adult
# 300    2      3       0  senior
# 301    1      3       0   adult
# 302    1      2       0   adult
#
# [303 rows x 15 columns]

# %%
# D'abord il faut les identifier
# isna() permet de renvoyer True ou False si les données sont manquantes ou non
# Ensuite sum() additionne le tout. False étant == 0 et True == 1 on peut en déduire le nombre d'élément manquant

df.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trtbps      0
# chol        0
# fbs         0
# restecg     0
# thalachh    0
# exng        0
# oldpeak     0
# slp         0
# caa         0
# thall       0
# output      0
# age_cat     0
# dtype: int64

# %%
# fillna() permet de remplacer des valeurs manquantes par une valeur choisie
# ici on choisir de remplacer par la moyenne
df['age'] = df['age'].fillna(df['age'].mean())
df
# Out:
#       age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0    63.0    1   3     145   233    1        0       150     0      2.3    0
# 1    63.0    1   2     130   250    0        1       187     0      3.5    0
# 2    63.0    0   1     130   204    0        0       172     0      1.4    2
# 3    63.0    1   1     120   236    0        1       178     0      0.8    2
# 4    63.0    0   0     120   354    0        1       163     1      0.6    2
# ..    ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298  63.0    0   0     140   241    0        1       123     1      0.2    1
# 299  63.0    1   3     110   264    0        1       132     0      1.2    1
# 300  68.0    1   0     144   193    1        1       141     0      3.4    1
# 301  63.0    1   0     130   131    0        1       115     1      1.2    1
# 302  63.0    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output age_cat
# 0      0      1       1   adult
# 1      0      2       1   adult
# 2      0      2       1   adult
# 3      0      2       1   adult
# 4      0      2       1   adult
# ..   ...    ...     ...     ...
# 298    0      3       0   adult
# 299    0      3       0   adult
# 300    2      3       0  senior
# 301    1      3       0   adult
# 302    1      2       0   adult
#
# [303 rows x 15 columns]

# %% [markdown]
# On pourrait également supprimer les valeurs manquantes.
#
# Attention à ne pas trop supprimer de lignes ou de colonnes.

# %%
df[['age']].sort_values()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[109], line 1
# ----> 1 df[['age']].sort_values()
#
# TypeError: DataFrame.sort_values() missing 1 required positional argument: 'by'

# %%
df[['age','cp','sex']].sort_values(by=['age','cp'],ascending=[False,True])
# Out:
#       age  cp  sex
# 238  77.0   0    1
# 144  76.0   2    0
# 129  74.0   1    0
# 151  71.0   0    0
# 25   71.0   1    0
# ..    ...  ..  ...
# 64   58.0   2    1
# 79   58.0   2    1
# 173  58.0   2    1
# 183  58.0   2    1
# 14   58.0   3    0
#
# [303 rows x 3 columns]

# %%
df.loc[df['age'] == 63, 'age'] = np.nan
df = df.dropna(subset=['age'])
df.sort_values(by=['age','chol'],ascending=[True,False])
# Out:
#       age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 16   58.0    0   2     120   340    0        1       172     0      0.0    2
# 278  58.0    0   1     136   319    1        0       152     0      0.0    2
# 291  58.0    1   0     114   318    0        2       140     0      4.4    0
# 236  58.0    1   0     125   300    0        0       171     0      0.0    2
# 172  58.0    1   1     120   284    0        0       160     0      1.8    1
# ..    ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 60   71.0    0   2     110   265    1        0       130     0      0.0    2
# 151  71.0    0   0     112   149    0        1       125     0      1.6    1
# 129  74.0    0   1     120   269    0        0       121     1      0.2    2
# 144  76.0    0   2     140   197    0        2       116     0      1.1    1
# 238  77.0    1   0     125   304    0        0       162     1      0.0    2
#
#      caa  thall  output age_cat
# 16     0      2       1   adult
# 278    2      2       0   adult
# 291    3      1       0   adult
# 236    2      3       0   adult
# 172    0      2       0   adult
# ..   ...    ...     ...     ...
# 60     1      2       1  senior
# 151    0      2       1  senior
# 129    1      2       1  senior
# 144    0      2       1  senior
# 238    3      2       0  senior
#
# [114 rows x 15 columns]

# %% [markdown]
# Nous sommes passés de 303 lignes à 114, ce qui fait beaucoup.
#
# Il serait plus sage de supprimer la colonne age plutôt que de supprimer chaque ligne où il y a une valeur manquante.

# %% [markdown]
# ## <u>6. Comment join plusieurs datasets </U>
#
# Fonctionnement identique au join SQL
#
# Illustation avec le pd.read_clipboard()
#
# PIB: https://fr.wikipedia.org/wiki/Produit_int%C3%A9rieur_brut
#
# Population: https://fr.wikipedia.org/wiki/Liste_des_pays_par_population

# %%
pib = pd.read_clipboard()
pib
# Out:
#                                                  Pays  2015  2020  2025
# 0                    Drapeau du Luxembourg Luxembourg   279   255   239
# 1                   Drapeau des États-Unis États-Unis   147   135   138
# 2                       Drapeau des Pays-Bas Pays-Bas   132   131   133
# 3                    Drapeau de l'Allemagne Allemagne   126   124   115
# 4                     Drapeau de la Belgique Belgique   119   118   114
# 5   Drapeau de l’Union européenne Union européenne...   100   100   100
# 6                  Drapeau du Royaume-Uni Royaume-Uni   111   102    99
# 7                         Drapeau de la France France   106   103    98
# 8                          Drapeau de l'Italie Italie    97    93    96
# 9                        Drapeau de l'Espagne Espagne    91    82    92
# 10                             Drapeau du Japon Japon   108    91    85
# 11                      Drapeau de la Pologne Pologne    70    78    81
# 12                      Drapeau de la Turquie Turquie    65    59    67

# %%
pib['Pays'] = pib['Pays'].apply(lambda x: x.split()[-1])
pib
# Out:
#            Pays  2015  2020  2025
# 0    Luxembourg   279   255   239
# 1    États-Unis   147   135   138
# 2      Pays-Bas   132   131   133
# 3     Allemagne   126   124   115
# 4      Belgique   119   118   114
# 5         pays)   100   100   100
# 6   Royaume-Uni   111   102    99
# 7        France   106   103    98
# 8        Italie    97    93    96
# 9       Espagne    91    82    92
# 10        Japon   108    91    85
# 11      Pologne    70    78    81
# 12      Turquie    65    59    67

# %%
pib = pib.drop(5)
pib
# Out:
#            Pays  2015  2020  2025
# 0    Luxembourg   279   255   239
# 1    États-Unis   147   135   138
# 2      Pays-Bas   132   131   133
# 3     Allemagne   126   124   115
# 4      Belgique   119   118   114
# 6   Royaume-Uni   111   102    99
# 7        France   106   103    98
# 8        Italie    97    93    96
# 9       Espagne    91    82    92
# 10        Japon   108    91    85
# 11      Pologne    70    78    81
# 12      Turquie    65    59    67

# %%
pib['Pays'].unique()
# Out:
# <StringArray>
# [ 'Luxembourg',  'États-Unis',    'Pays-Bas',   'Allemagne',    'Belgique',
#  'Royaume-Uni',      'France',      'Italie',     'Espagne',       'Japon',
#      'Pologne',     'Turquie']
# Length: 12, dtype: str

# %%
pib
# Out:
#            Pays  2015  2020  2025
# 0    Luxembourg   279   255   239
# 1    États-Unis   147   135   138
# 2      Pays-Bas   132   131   133
# 3     Allemagne   126   124   115
# 4      Belgique   119   118   114
# 6   Royaume-Uni   111   102    99
# 7        France   106   103    98
# 8        Italie    97    93    96
# 9       Espagne    91    82    92
# 10        Japon   108    91    85
# 11      Pologne    70    78    81
# 12      Turquie    65    59    67

# %%
# Depivotage
pib.melt(id_vars=['Pays'],value_vars=pib.drop(columns=['Pays']).columns,var_name='Annee').sort_values(by=['Pays'])
# Out:
#            Pays Annee  value
# 14    Allemagne  2019    122
# 3     Allemagne  2014    128
# 25    Allemagne  2024    116
# 2      Belgique  2014    121
# 13     Belgique  2019    117
# 24     Belgique  2024    117
# 18      Espagne  2019     91
# 29      Espagne  2024     91
# 7       Espagne  2014     90
# 27       France  2024     98
# 16       France  2019    105
# 5        France  2014    108
# 6        Italie  2014     98
# 17       Italie  2019     96
# 28       Italie  2024     98
# 8         Japon  2014    106
# 30        Japon  2024     82
# 19        Japon  2019     88
# 22   Luxembourg  2024    245
# 0    Luxembourg  2014    280
# 11   Luxembourg  2019    249
# 20      Pologne  2019     74
# 9       Pologne  2014     68
# 31      Pologne  2024     78
# 15  Royaume-Uni  2019    103
# 26  Royaume-Uni  2024     99
# 4   Royaume-Uni  2014    110
# 21      Turquie  2019     59
# 10      Turquie  2014     64
# 32      Turquie  2024     72
# 23   États-Unis  2024    135
# 12   États-Unis  2019    134
# 1    États-Unis  2014    147

# %%
pib.pivot_table() # Inverse d'un melt
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[129], line 1
# ----> 1 pib.pivot_table()
#
# File c:\Users\e.vervaeren\Desktop\Learning-IOT-AI-Architect\Python\pyhton_data_science\.venv\Lib\site-packages\pandas\core\frame.py:11161, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort, **kwargs)
#   11157         **kwargs,
#   11158     ) -> DataFrame:
#   11159         from pandas.core.reshape.pivot import pivot_table
#   11160
# > 11161         return pivot_table(
#   11162             self,
#   11163             values=values,
#   11164             index=index,
#
# File c:\Users\e.vervaeren\Desktop\Learning-IOT-AI-Architect\Python\pyhton_data_science\.venv\Lib\site-packages\pandas\core\reshape\pivot.py:267, in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort, **kwargs)
#     264     table = concat(pieces, keys=keys, axis=1)
#     265     return table.__finalize__(data, method="pivot_table")
# --> 267 table = __internal_pivot_table(
#     268     data,
#     269     values,
#     270     index,
#     271     columns,
#     272     aggfunc,
#     273     fill_value,
#     274     margins,
#     275     dropna,
#     276     margins_name,
#     277     observed,
#     278     sort,
#     279     kwargs,
#     280 )
#     281 return table.__finalize__(data, method="pivot_table")
#
# File c:\Users\e.vervaeren\Desktop\Learning-IOT-AI-Architect\Python\pyhton_data_science\.venv\Lib\site-packages\pandas\core\reshape\pivot.py:338, in __internal_pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort, kwargs)
#     335             pass
#     336     values = list(values)
# --> 338 grouped = data.groupby(keys, observed=observed, sort=sort, dropna=dropna)
#     339 if values_passed:
#     340     # GH#57876 and GH#61292
#     341     # mypy is not aware `grouped[values]` will always be a DataFrameGroupBy
#     342     grouped = grouped[values]  # type: ignore[assignment]
#
# File c:\Users\e.vervaeren\Desktop\Learning-IOT-AI-Architect\Python\pyhton_data_science\.venv\Lib\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File c:\Users\e.vervaeren\Desktop\Learning-IOT-AI-Architect\Python\pyhton_data_science\.venv\Lib\site-packages\pandas\core\frame.py:10835, in DataFrame.groupby(self, by, level, as_index, sort, group_keys, observed, dropna)
#   10831
#   10832         if level is None and by is None:
#   10833             raise TypeError("You have to supply one of 'by' and 'level'")
#   10834
# > 10835         return DataFrameGroupBy(
#   10836             obj=self,
#   10837             keys=by,
#   10838             level=level,
#
# File c:\Users\e.vervaeren\Desktop\Learning-IOT-AI-Architect\Python\pyhton_data_science\.venv\Lib\site-packages\pandas\core\groupby\groupby.py:1095, in GroupBy.__init__(self, obj, keys, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1092 self.dropna = dropna
#    1094 if grouper is None:
# -> 1095     grouper, exclusions, obj = get_grouper(
#    1096         obj,
#    1097         keys,
#    1098         level=level,
#    1099         sort=sort,
#    1100         observed=observed,
#    1101         dropna=self.dropna,
#    1102     )
#    1104 self.observed = observed
#    1105 self.obj = obj
#
# File c:\Users\e.vervaeren\Desktop\Learning-IOT-AI-Architect\Python\pyhton_data_science\.venv\Lib\site-packages\pandas\core\groupby\grouper.py:929, in get_grouper(obj, key, level, sort, observed, validate, dropna)
#     926     groupings.append(ping)
#     928 if len(groupings) == 0 and len(obj):
# --> 929     raise ValueError("No group keys passed!")
#     930 if len(groupings) == 0:
#     931     groupings.append(Grouping(default_index(0), np.array([], dtype=np.intp)))
#
# ValueError: No group keys passed!

# %%
url = 'https://fr.wikipedia.org/wiki/Liste_des_pays_par_population'
response = rq.get(url,headers={'User-Agent': 'Mozilla/5.0'})
data = pd.read_html(StringIO(response.text))
population = data[0]
population
# Out:
#     Rang (2023) Pays ou territoire Population au 1er juillet 2023  \
# 0             -              Monde                  8 091 734 930
# 1             1            Inde[a]                  1 438 069 596
# 2             2           Chine[b]                  1 422 584 933
# 3             3      États-Unis[c]                    343 477 335
# 4             4          Indonésie                    281 190 067
# ..          ...                ...                            ...
# 233           -         Montserrat                          4 420
# 234           -     Îles Malouines                          3 477
# 235           -            Tokelau                          2 397
# 236         199               Niue                          1 817
# 237         200            Vatican                            496
#
#     Population projetée au 1er juillet 2026
# 0                             8 300 678 395
# 1                             1 476 625 576
# 2                             1 412 914 089
# 3                               349 035 494
# 4                               287 886 782
# ..                                      ...
# 233                                   4 328
# 234                                   3 465
# 235                                   2 691
# 236                                   1 822
# 237                                     506
#
# [238 rows x 4 columns]

# %%
population['Pays ou territoire'] = population['Pays ou territoire'].str.replace(r'\[.*\]', '',regex=True).str.strip()

# %%
population
# Out:
#     Rang (2023) Pays ou territoire Population au 1er juillet 2023  \
# 0             -              Monde                  8 091 734 930
# 1             1               Inde                  1 438 069 596
# 2             2              Chine                  1 422 584 933
# 3             3         États-Unis                    343 477 335
# 4             4          Indonésie                    281 190 067
# ..          ...                ...                            ...
# 233           -         Montserrat                          4 420
# 234           -     Îles Malouines                          3 477
# 235           -            Tokelau                          2 397
# 236         199               Niue                          1 817
# 237         200            Vatican                            496
#
#     Population projetée au 1er juillet 2026
# 0                             8 300 678 395
# 1                             1 476 625 576
# 2                             1 412 914 089
# 3                               349 035 494
# 4                               287 886 782
# ..                                      ...
# 233                                   4 328
# 234                                   3 465
# 235                                   2 691
# 236                                   1 822
# 237                                     506
#
# [238 rows x 4 columns]

# %%
print(list(population))
print(list(pib))
finaldf = pib.merge(population, how='left', left_on='Pays', right_on='Pays ou territoire')
finaldf
# Out:
# ['Rang (2023)', 'Pays ou territoire', 'Population au 1er juillet 2023', 'Population projetée au 1er juillet 2026']
# ['Pays', '2015', '2020', '2025']
#            Pays  2015  2020  2025 Rang (2023) Pays ou territoire  \
# 0    Luxembourg   279   255   239         165         Luxembourg
# 1    États-Unis   147   135   138           3         États-Unis
# 2      Pays-Bas   132   131   133          70           Pays-Bas
# 3     Allemagne   126   124   115          19          Allemagne
# 4      Belgique   119   118   114          81           Belgique
# 5   Royaume-Uni   111   102    99          21        Royaume-Uni
# 6        France   106   103    98          23             France
# 7        Italie    97    93    96          25             Italie
# 8       Espagne    91    82    92          32            Espagne
# 9         Japon   108    91    85          12              Japon
# 10      Pologne    70    78    81          39            Pologne
# 11      Turquie    65    59    67          18            Turquie
#
#    Population au 1er juillet 2023 Population projetée au 1er juillet 2026
# 0                         665 098                                 687 448
# 1                     343 477 335                             349 035 494
# 2                      18 092 524                              18 448 775
# 3                      84 548 231                              83 644 258
# 4                      11 712 893                              11 774 642
# 5                      68 682 962                              69 931 528
# 6                      66 438 822                              66 746 401
# 7                      59 499 453                              58 926 166
# 8                      47 911 579                              47 850 793
# 9                     124 370 947                             122 427 731
# 10                     38 762 844                              37 843 188
# 11                     87 270 501                              87 926 082

# %%
finaldf = finaldf.rename(columns={'Rang (2023)':'Rang population'})
finaldf
# Out:
#            Pays  2015  2020  2025 Rang population Pays ou territoire  \
# 0    Luxembourg   279   255   239             165         Luxembourg
# 1    États-Unis   147   135   138               3         États-Unis
# 2      Pays-Bas   132   131   133              70           Pays-Bas
# 3     Allemagne   126   124   115              19          Allemagne
# 4      Belgique   119   118   114              81           Belgique
# 5   Royaume-Uni   111   102    99              21        Royaume-Uni
# 6        France   106   103    98              23             France
# 7        Italie    97    93    96              25             Italie
# 8       Espagne    91    82    92              32            Espagne
# 9         Japon   108    91    85              12              Japon
# 10      Pologne    70    78    81              39            Pologne
# 11      Turquie    65    59    67              18            Turquie
#
#    Population au 1er juillet 2023 Population projetée au 1er juillet 2026
# 0                         665 098                                 687 448
# 1                     343 477 335                             349 035 494
# 2                      18 092 524                              18 448 775
# 3                      84 548 231                              83 644 258
# 4                      11 712 893                              11 774 642
# 5                      68 682 962                              69 931 528
# 6                      66 438 822                              66 746 401
# 7                      59 499 453                              58 926 166
# 8                      47 911 579                              47 850 793
# 9                     124 370 947                             122 427 731
# 10                     38 762 844                              37 843 188
# 11                     87 270 501                              87 926 082

# %%
finaldf.to_csv("country_pib.csv")

# %% [markdown]
# ## <u>7. connection db </U>
#
# <br>
#
# Créer une connecteur sur base d'une URL avec comme information:
# - le SGBD
# - username+password
# - adresse réseau
# - le nom de la db à laquelle se connecter
#
# E.g.:
# - postgresql://username:password@localhost:5432/db_name # localhost=127.0.0.1
# - mssql+pyodbc://username:password@localhost:1433/db_name
# - mssql+pyodbc://server_name/db_name?trusted_connection=yes # auth windows
# - mssql+pyodbc://server_name/db_name?trusted_connection=yes&driver=ODBC+Driver+17+for+SQL+Server # Avec driver ODBC spécifique

# %%
from dotenv import load_dotenv

# %%
sgbd = 'postgresql'
server_name = r'ERNEST\DATA'
db_name = 'DBPandas'
driver = 'ODBC+Driver+17+for+SQL+Server'

url = f'{sgbd}://{server_name}/{db_name}?trusted_connection=yes&driver={driver}'
con = create_engine(url)

sql_query = "SELECT * FROM student WHERE year_result > 15"
data = pd.read_sql(sql_query,con)

con.dispose() # release con

data
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\Users\e.vervaeren\Desktop\Learning-IOT-AI-Architect\Python\pyhton_data_science\.venv\Lib\site-packages\sqlalchemy\engine\base.py:144, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     143 try:
# --> 144     self._dbapi_connection = engine.raw_connection()
#     145 except dialect.loaded_dbapi.Error as err:
#
# File c:\Users\e.vervaeren\Desktop\Learning-IOT-AI-Architect\Python\pyhton_data_science\.venv\Lib\site-packages\sqlalchemy\engine\base.py:3319, in Engine.raw_connection(self)
#    3298 """Return a "raw" DBAPI connection from the connection pool.
#    3299
#    3300 The returned object is a proxied version of the DBAPI
#    (...)   3317
#    3318 """
# -> 3319 return self.pool.connect()
#
# File c:\Users\e.vervaeren\Desktop\Learning-IOT-AI-Architect\Python\pyhton_data_science\.venv\Lib\site-packages\sqlalchemy\pool\base.py:448, in Pool.connect(self)
#     441 """Return a DBAPI connection from the pool.
#     442
#     443 The connection is instrumented such that when its
#    (...)    446
#     447 """
# --> 448 return _ConnectionFairy._checkout(self)
#
# File c:\Users\e.vervaeren\Desktop\Learning-IOT-AI-Architect\Python\pyhton_data_science\.venv\Lib\site-packages\sqlalchemy\pool\base.py:1272, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1271 if not fairy:
# -> 1272     fairy = _ConnectionRecord.checkout(pool)
#    1274     if threadconns is not None:
#
# File c:\Users\e.vervaeren\Desktop\Learning-IOT-AI-Architect\Python\pyhton_data_science\.venv\Lib\site-packages\sqlalchemy\pool\base.py:712, in _ConnectionRecord.checkout(cls, pool)
#     711 else:
# --> 712     rec = pool._do_get()
#     714 try:
#
# File c:\Users\e.vervaeren\Desktop\Learning-IOT-AI-Architect\Python\pyhton_data_science\.venv\Lib\site-packages\sqlalchemy\pool\impl.py:178, in QueuePool._do_get(self)
#     177 except:
# --> 178     with util.safe_reraise():
#     179         self._dec_overflow()
#
# File c:\Users\e.vervaeren\Desktop\Learning-IOT-AI-Architect\Python\pyhton_data_science\.venv\Lib\site-packages\sqlalchemy\util\langhelpers.py:122, in safe_reraise.__exit__(self, type_, value, traceback)
#     121     self._exc_info = None  # remove potential circular references
# --> 122     raise exc_value.with_traceback(exc_tb)
#     123 else:
#
# File c:\Users\e.vervaeren\Desktop\Learning-IOT-AI-Architect\Python\pyhton_data_science\.venv\Lib\site-packages\sqlalchemy\pool\impl.py:176, in QueuePool._do_get(self)
#     175 try:
# --> 176     return self._create_connection()
#     177 except:
#
# File c:\Users\e.vervaeren\Desktop\Learning-IOT-AI-Architect\Python\pyhton_data_science\.venv\Lib\site-packages\sqlalchemy\pool\base.py:389, in Pool._create_connection(self)
#     387 """Called by subclasses to create a new ConnectionRecord."""
# --> 389 return _ConnectionRecord(self)
#
# File c:\Users\e.vervaeren\Desktop\Learning-IOT-AI-Architect\Python\pyhton_data_science\.venv\Lib\site-packages\sqlalchemy\pool\base.py:674, in _ConnectionRecord.__init__(self, pool, connect)
#     673 if connect:
# --> 674     self.__connect()
#     675 self.finalize_callback = deque()
#
# File c:\Users\e.vervaeren\Desktop\Learning-IOT-AI-Architect\Python\pyhton_data_science\.venv\Lib\site-packages\sqlalchemy\pool\base.py:900, in _ConnectionRecord.__connect(self)
#     899 except BaseException as e:
# --> 900     with util.safe_reraise():
#     901         pool.logger.debug("Error on connect(): %s", e)
#
# File c:\Users\e.vervaeren\Desktop\Learning-IOT-AI-Architect\Python\pyhton_data_science\.venv\Lib\site-packages\sqlalchemy\util\langhelpers.py:122, in safe_reraise.__exit__(self, type_, value, traceback)
#     121     self._exc_info = None  # remove potential circular references
# --> 122     raise exc_value.with_traceback(exc_tb)
#     123 else:
#
# File c:\Users\e.vervaeren\Desktop\Learning-IOT-AI-Architect\Python\pyhton_data_science\.venv\Lib\site-packages\sqlalchemy\pool\base.py:896, in _ConnectionRecord.__connect(self)
#     895 self.starttime = time.time()
# --> 896 self.dbapi_connection = connection = pool._invoke_creator(self)
#     897 pool.logger.debug("Created new connection %r", connection)
#
# File c:\Users\e.vervaeren\Desktop\Learning-IOT-AI-Architect\Python\pyhton_data_science\.venv\Lib\site-packages\sqlalchemy\engine\create.py:667, in create_engine.<locals>.connect(connection_record)
#     666 else:
# --> 667     return dialect.connect(*cargs_tup, **cparams)
#
# File c:\Users\e.vervaeren\Desktop\Learning-IOT-AI-Architect\Python\pyhton_data_science\.venv\Lib\site-packages\sqlalchemy\engine\default.py:630, in DefaultDialect.connect(self, *cargs, **cparams)
#     628 def connect(self, *cargs: Any, **cparams: Any) -> DBAPIConnection:
#     629     # inherits the docstring from interfaces.Dialect.connect
# --> 630     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# OperationalError: ('08001', '[08001] [Microsoft][ODBC Driver 17 for SQL Server]SQL Server Network Interfaces: Error Locating Server/Instance Specified [xFFFFFFFF].  (-1) (SQLDriverConnect); [08001] [Microsoft][ODBC Driver 17 for SQL Server]Login timeout expired (0); [08001] [Microsoft][ODBC Driver 17 for SQL Server]A network-related or instance-specific error has occurred while establishing a connection to SQL Server. Server is not found or not accessible. Check if instance name is correct and if SQL Server is configured to allow remote connections. For more information see SQL Server Books Online. (-1)')
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[141], line 10
#       6 url = f'{sgbd}://{server_name}/{db_name}?trusted_connection=yes&driver={driver}'
#       7 con = create_engine(url)
#       8
#       9 sql_query = "SELECT * FROM student WHERE year_result > 15"
# ---> 10 data = pd.read_sql(sql_query,con)
#      11
#      12 con.dispose() # release con
#      13
#
# File c:\Users\e.vervaeren\Desktop\Learning-IOT-AI-Architect\Python\pyhton_data_science\.venv\Lib\site-packages\pandas\io\sql.py:700, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     697     dtype_backend = "numpy"  # type: ignore[assignment]
#     698 assert dtype_backend is not lib.no_default
# --> 700 with pandasSQL_builder(con) as pandas_sql:
#     701     if isinstance(pandas_sql, SQLiteDatabase):
#     702         return pandas_sql.read_query(
#     703             sql,
#     704             index_col=index_col,
#    (...)    710             dtype=dtype,
#     711         )
#
# File c:\Users\e.vervaeren\Desktop\Learning-IOT-AI-Architect\Python\pyhton_data_science\.venv\Lib\site-packages\pandas\io\sql.py:908, in pandasSQL_builder(con, schema, need_transaction)
#     902     raise ImportError(
#     903         f"Using URI string without version '{VERSIONS['sqlalchemy']}' or newer "
#     904         "of 'sqlalchemy' installed."
#     905     )
#     907 if sqlalchemy is not None and isinstance(con, (str, sqlalchemy.engine.Connectable)):
# --> 908     return SQLDatabase(con, schema, need_transaction)
#     910 adbc = import_optional_dependency("adbc_driver_manager.dbapi", errors="ignore")
#     911 if adbc and isinstance(con, adbc.Connection):
#
# File c:\Users\e.vervaeren\Desktop\Learning-IOT-AI-Architect\Python\pyhton_data_science\.venv\Lib\site-packages\pandas\io\sql.py:1649, in SQLDatabase.__init__(self, con, schema, need_transaction)
#    1647     self.exit_stack.callback(con.dispose)
#    1648 if isinstance(con, Engine):
# -> 1649     con = self.exit_stack.enter_context(con.connect())
#    1650 if need_transaction and not con.in_transaction():
#    1651     self.exit_stack.enter_context(con.begin())
#
# File c:\Users\e.vervaeren\Desktop\Learning-IOT-AI-Architect\Python\pyhton_data_science\.venv\Lib\site-packages\sqlalchemy\engine\base.py:3295, in Engine.connect(self)
#    3272 def connect(self) -> Connection:
#    3273     """Return a new :class:`_engine.Connection` object.
#    3274
#    3275     The :class:`_engine.Connection` acts as a Python context manager, so
#    (...)   3292
#    3293     """
# -> 3295     return self._connection_cls(self)
#
# File c:\Users\e.vervaeren\Desktop\Learning-IOT-AI-Architect\Python\pyhton_data_science\.venv\Lib\site-packages\sqlalchemy\engine\base.py:146, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144         self._dbapi_connection = engine.raw_connection()
#     145     except dialect.loaded_dbapi.Error as err:
# --> 146         Connection._handle_dbapi_exception_noconnection(
#     147             err, dialect, engine
#     148         )
#     149         raise
#     150 else:
#
# File c:\Users\e.vervaeren\Desktop\Learning-IOT-AI-Architect\Python\pyhton_data_science\.venv\Lib\site-packages\sqlalchemy\engine\base.py:2450, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine, is_disconnect, invalidate_pool_on_disconnect, is_pre_ping)
#    2448 elif should_wrap:
#    2449     assert sqlalchemy_exception is not None
# -> 2450     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2451 else:
#    2452     assert exc_info[1] is not None
#
# File c:\Users\e.vervaeren\Desktop\Learning-IOT-AI-Architect\Python\pyhton_data_science\.venv\Lib\site-packages\sqlalchemy\engine\base.py:144, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     142 if connection is None:
#     143     try:
# --> 144         self._dbapi_connection = engine.raw_connection()
#     145     except dialect.loaded_dbapi.Error as err:
#     146         Connection._handle_dbapi_exception_noconnection(
#     147             err, dialect, engine
#     148         )
#
# File c:\Users\e.vervaeren\Desktop\Learning-IOT-AI-Architect\Python\pyhton_data_science\.venv\Lib\site-packages\sqlalchemy\engine\base.py:3319, in Engine.raw_connection(self)
#    3297 def raw_connection(self) -> PoolProxiedConnection:
#    3298     """Return a "raw" DBAPI connection from the connection pool.
#    3299
#    3300     The returned object is a proxied version of the DBAPI
#    (...)   3317
#    3318     """
# -> 3319     return self.pool.connect()
#
# File c:\Users\e.vervaeren\Desktop\Learning-IOT-AI-Architect\Python\pyhton_data_science\.venv\Lib\site-packages\sqlalchemy\pool\base.py:448, in Pool.connect(self)
#     440 def connect(self) -> PoolProxiedConnection:
#     441     """Return a DBAPI connection from the pool.
#     442
#     443     The connection is instrumented such that when its
#    (...)    446
#     447     """
# --> 448     return _ConnectionFairy._checkout(self)
#
# File c:\Users\e.vervaeren\Desktop\Learning-IOT-AI-Architect\Python\pyhton_data_science\.venv\Lib\site-packages\sqlalchemy\pool\base.py:1272, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1264 @classmethod
#    1265 def _checkout(
#    1266     cls,
#    (...)   1269     fairy: Optional[_ConnectionFairy] = None,
#    1270 ) -> _ConnectionFairy:
#    1271     if not fairy:
# -> 1272         fairy = _ConnectionRecord.checkout(pool)
#    1274         if threadconns is not None:
#    1275             threadconns.current = weakref.ref(fairy)
#
# File c:\Users\e.vervaeren\Desktop\Learning-IOT-AI-Architect\Python\pyhton_data_science\.venv\Lib\site-packages\sqlalchemy\pool\base.py:712, in _ConnectionRecord.checkout(cls, pool)
#     710     rec = cast(_ConnectionRecord, pool._do_get())
#     711 else:
# --> 712     rec = pool._do_get()
#     714 try:
#     715     dbapi_connection = rec.get_connection()
#
# File c:\Users\e.vervaeren\Desktop\Learning-IOT-AI-Architect\Python\pyhton_data_science\.venv\Lib\site-packages\sqlalchemy\pool\impl.py:178, in QueuePool._do_get(self)
#     176     return self._create_connection()
#     177 except:
# --> 178     with util.safe_reraise():
#     179         self._dec_overflow()
#     180     raise
#
# File c:\Users\e.vervaeren\Desktop\Learning-IOT-AI-Architect\Python\pyhton_data_science\.venv\Lib\site-packages\sqlalchemy\util\langhelpers.py:122, in safe_reraise.__exit__(self, type_, value, traceback)
#     120     assert exc_value is not None
#     121     self._exc_info = None  # remove potential circular references
# --> 122     raise exc_value.with_traceback(exc_tb)
#     123 else:
#     124     self._exc_info = None  # remove potential circular references
#
# File c:\Users\e.vervaeren\Desktop\Learning-IOT-AI-Architect\Python\pyhton_data_science\.venv\Lib\site-packages\sqlalchemy\pool\impl.py:176, in QueuePool._do_get(self)
#     174 if self._inc_overflow():
#     175     try:
# --> 176         return self._create_connection()
#     177     except:
#     178         with util.safe_reraise():
#
# File c:\Users\e.vervaeren\Desktop\Learning-IOT-AI-Architect\Python\pyhton_data_science\.venv\Lib\site-packages\sqlalchemy\pool\base.py:389, in Pool._create_connection(self)
#     386 def _create_connection(self) -> ConnectionPoolEntry:
#     387     """Called by subclasses to create a new ConnectionRecord."""
# --> 389     return _ConnectionRecord(self)
#
# File c:\Users\e.vervaeren\Desktop\Learning-IOT-AI-Architect\Python\pyhton_data_science\.venv\Lib\site-packages\sqlalchemy\pool\base.py:674, in _ConnectionRecord.__init__(self, pool, connect)
#     672 self.__pool = pool
#     673 if connect:
# --> 674     self.__connect()
#     675 self.finalize_callback = deque()
#
# File c:\Users\e.vervaeren\Desktop\Learning-IOT-AI-Architect\Python\pyhton_data_science\.venv\Lib\site-packages\sqlalchemy\pool\base.py:900, in _ConnectionRecord.__connect(self)
#     898     self.fresh = True
#     899 except BaseException as e:
# --> 900     with util.safe_reraise():
#     901         pool.logger.debug("Error on connect(): %s", e)
#     902 else:
#     903     # in SQLAlchemy 1.4 the first_connect event is not used by
#     904     # the engine, so this will usually not be set
#
# File c:\Users\e.vervaeren\Desktop\Learning-IOT-AI-Architect\Python\pyhton_data_science\.venv\Lib\site-packages\sqlalchemy\util\langhelpers.py:122, in safe_reraise.__exit__(self, type_, value, traceback)
#     120     assert exc_value is not None
#     121     self._exc_info = None  # remove potential circular references
# --> 122     raise exc_value.with_traceback(exc_tb)
#     123 else:
#     124     self._exc_info = None  # remove potential circular references
#
# File c:\Users\e.vervaeren\Desktop\Learning-IOT-AI-Architect\Python\pyhton_data_science\.venv\Lib\site-packages\sqlalchemy\pool\base.py:896, in _ConnectionRecord.__connect(self)
#     894 try:
#     895     self.starttime = time.time()
# --> 896     self.dbapi_connection = connection = pool._invoke_creator(self)
#     897     pool.logger.debug("Created new connection %r", connection)
#     898     self.fresh = True
#
# File c:\Users\e.vervaeren\Desktop\Learning-IOT-AI-Architect\Python\pyhton_data_science\.venv\Lib\site-packages\sqlalchemy\engine\create.py:667, in create_engine.<locals>.connect(connection_record)
#     665     return dialect.connect(*mutable_cargs, **mutable_cparams)
#     666 else:
# --> 667     return dialect.connect(*cargs_tup, **cparams)
#
# File c:\Users\e.vervaeren\Desktop\Learning-IOT-AI-Architect\Python\pyhton_data_science\.venv\Lib\site-packages\sqlalchemy\engine\default.py:630, in DefaultDialect.connect(self, *cargs, **cparams)
#     628 def connect(self, *cargs: Any, **cparams: Any) -> DBAPIConnection:
#     629     # inherits the docstring from interfaces.Dialect.connect
# --> 630     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# OperationalError: (pyodbc.OperationalError) ('08001', '[08001] [Microsoft][ODBC Driver 17 for SQL Server]SQL Server Network Interfaces: Error Locating Server/Instance Specified [xFFFFFFFF].  (-1) (SQLDriverConnect); [08001] [Microsoft][ODBC Driver 17 for SQL Server]Login timeout expired (0); [08001] [Microsoft][ODBC Driver 17 for SQL Server]A network-related or instance-specific error has occurred while establishing a connection to SQL Server. Server is not found or not accessible. Check if instance name is correct and if SQL Server is configured to allow remote connections. For more information see SQL Server Books Online. (-1)')
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
