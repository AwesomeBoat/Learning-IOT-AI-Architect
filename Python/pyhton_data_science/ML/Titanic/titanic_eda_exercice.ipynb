# %% [markdown]
# # Titanic EDA — Exercices
#
# Ce notebook a pour objectif de pratiquer une **analyse exploratoire de données (EDA)**
# sur le dataset `Titanic` disponible directement via `seaborn`.
#
# Vous travaillerez avec les librairies :
# - `pandas`
# - `seaborn`
# - `matplotlib`
#
# L'objectif est de :
# 1. Charger et explorer le dataset.
# 2. Réaliser des statistiques descriptives.
# 3. Visualiser la répartition des variables.
# 4. Identifier des corrélations potentielles.
# 5. Mettre en avant des facteurs influençant la survie.
#
# Les cellules de code sont volontairement laissées incomplètes. C’est à vous de les remplir !

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Charger le dataset Titanic depuis seaborn
titanic = sns.load_dataset("titanic")

# Afficher les 5 premières lignes
titanic.head()

# %% [markdown]
# ## 1. Exploration initiale
#
# 1. Affichez les **informations générales** sur le dataset (`.info()`).
# 2. Donnez le **nombre de lignes et de colonnes**.
# 3. Listez les **valeurs manquantes** (nombre et pourcentage par variable).
# 4. Affichez les **5 premières lignes** du dataset.

# %%
# À compléter

# %% [markdown]
# ## 2. Statistiques descriptives
#
# 1. Calculez les statistiques descriptives globales avec `.describe()`.
# 2. Observez la distribution de l'âge : moyenne, médiane, écart-type.
# 3. Analysez la variable `fare` (prix du billet) : min, max, quartiles.
# 4. Comptez le nombre de passagers par `class`.
# 5. Calculez le pourcentage de survie global (`survived`).

# %%
# À compléter

# %% [markdown]
# ## 3. Visualisations univariées
#
# Réalisez des graphiques simples pour comprendre la distribution des variables :
#
# 1. Histogramme des âges (`sns.histplot`).
# 2. Distribution du prix des billets (`sns.histplot`, en log si nécessaire).
# 3. Répartition des passagers par classe (`sns.countplot`).
# 4. Répartition du nombre de survivants (`sns.countplot`).

# %%
# À compléter

# %% [markdown]
# ## 4. Relations entre variables
#
# Étudiez maintenant les relations entre certaines variables :
#
# 1. Survie en fonction du sexe (`sns.countplot` avec `hue`).
# 2. Survie en fonction de la classe (`sns.countplot` avec `hue`).
# 3. Distribution des âges selon la survie (`sns.boxplot`).
# 4. Prix du billet selon la survie (`sns.violinplot`).

# %%
# À compléter

# %% [markdown]
# ## 5. Analyses croisées
#
# 1. Comparez la **survie** selon le couple `(sex, class)` (`sns.catplot`).
# 2. Étudiez la relation entre `sibsp` (frères/sœurs/conjoints) et survie.
# 3. Étudiez la relation entre `parch` (parents/enfants) et survie.
# 4. Utilisez `pd.crosstab` pour résumer la survie par sexe et par classe.

# %%
# À compléter

# %% [markdown]
# ## 6. Corrélations
#
# 1. Calculez la matrice de corrélation (`.corr()`).
# 2. Visualisez-la avec une heatmap (`sns.heatmap`).
# 3. Identifiez les variables les plus corrélées avec la survie.

# %%
# À compléter

# %% [markdown]
# ## 7. Conclusion
#
# - Quelles variables semblent les plus déterminantes pour expliquer la survie ?
# - Quels profils de passagers avaient le plus de chances de survivre ?
# - Quelles variables mériteraient un traitement supplémentaire avant une modélisation (valeurs manquantes, normalisation, etc.) ?
